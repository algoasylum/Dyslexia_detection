# %%
from scipy import signal
import matplotlib.pyplot as plt

import glob
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly
from scipy.spatial.distance import euclidean as eu
import math

# %%
Fs = 2
t = np.linspace(0,399,400)
f = 10/400
x =5*(np.sin(2*np.pi*f*t))#+(np.sin(2*np.pi*20*t))
y =(np.sin(2*np.pi*50*t))+(np.sin(2*np.pi*60*t))
#x = x+y

# %%
t.shape
# Out:
# (400,)

# %%
plt.plot(t,x)

# %%
Z = np.fft.fft(x)

# %%
Z_norm = abs(Z)
Z_norm = Z_norm/ max(Z_norm)

# %%
plt.plot(Z_norm)

# %%
data = Z_norm
L= len(data)
#k = int((len(data) + 1)/250) # k varies from 4 to 8
N=20
B  = 40
E =0#round((N*B - L)/(N-1))
print(B)
print(E)
print(L)
max(np.abs(data))
# Out:
# 40
# 0
# 400
# 1.0

# %%
f, t, Zxx = signal.stft(x,fs =1, nperseg=B,noverlap= E)
print(len(t))
print(len(data))
X =plt.pcolormesh(t, f, np.abs(Zxx) ,vmax=max(np.abs(data)),shading='gouraud')
plt.title('STFT Magnitude')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()
# Out:
# 11
# 400

# %%
data = Z_norm
L= len(data)
#k = int((len(data) + 1)/250) # k varies from 4 to 8
N=20
B  = 20
E =0#round((N*B - L)/(N-1))
print(B)
print(E)
print(L)
max(np.abs(data))
# Out:
# 20
# 0
# 400
# 1.0

# %%
f, t, Zxx = signal.stft(x,fs = 10, nperseg=B,noverlap= E)
print(len(t))
print(len(data))
X =plt.pcolormesh(t, f, np.abs(Zxx)**2 ,vmax=max(np.abs(data)),shading='gouraud')
plt.title('STFT Magnitude')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()
# Out:
# 21
# 400

# %%
data = Z_norm
L= len(data)
#k = int((len(data) + 1)/250) # k varies from 4 to 8
N=20
B  = 10
E =0#round((N*B - L)/(N-1))
print(B)
print(E)
print(L)
max(np.abs(data))
# Out:
# 10
# 0
# 400
# 1.0

# %%
f, t, Zxx = signal.stft(x,fs = 1, nperseg=B,noverlap= E)
print(len(t))
print(len(data))
X =plt.pcolormesh(t, f, np.abs(Zxx)**2 ,vmax=max(np.abs(data)),shading='gouraud')
plt.title('STFT Magnitude')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()
# Out:
# 41
# 400

# %%
data = Z_norm
L= len(data)
#k = int((len(data) + 1)/250) # k varies from 4 to 8
N=20
B  =40
E =0#round((N*B - L)/(N-1))
print(B)
print(E)
print(L)
max(np.abs(data))
f, t, Zxx = signal.stft(x,fs = 1, nperseg=B,noverlap= E)
print(len(t))
print(len(data))
X =plt.pcolormesh(t, f, np.abs(Zxx) ,vmax=max(np.abs(data)),shading='gouraud')
plt.title('STFT Magnitude')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.ylim([0,0.1])
plt.show()
# Out:
# 40
# 0
# 400
# 11
# 400

# %%
data = Z_norm
L= len(data)
#k = int((len(data) + 1)/250) # k varies from 4 to 8
N=20
B  = 30
E =0#round((N*B - L)/(N-1))
print(B)
print(E)
print(L)
max(np.abs(data))
# Out:
# 30
# 0
# 400
# 1.0

# %%
f, t, Zxx = signal.stft(x,fs = 1, nperseg=B,noverlap= E)
print(len(t))
print(len(data))
X =plt.pcolormesh(t, f, np.abs(Zxx)**2 ,vmax=max(np.abs(data)),shading='gouraud')
plt.title('STFT Magnitude')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()
# Out:
# 15
# 400

# %%
Fs = 2
t = np.linspace(0,399,400)
f = 10/400
x =(np.sin(2*np.pi*f*t))
plt.plot(x)

# %%
y = np.zeros(400)
y[200] = 1
y[201] = 1
y[202] = 1
plt.plot(y)

# %%
from scipy.signal import chirp
t = np.linspace(0, 400, 400)
w = chirp(t, f0=1/10, f1=1/80, t1=400, method='linear')
plt.plot(t, w)
plt.xlabel('t (sec)')
plt.show()

# %%
x.shape
# Out:
# (400,)

# %%
w.shape
# Out:
# (400,)

# %%
z = x+w+y
plt.plot(z)

# %%
Z = np.fft.fft(z)
Z_norm = abs(Z)
Z_norm = Z_norm/ max(Z_norm)
plt.plot(Z_norm)

# %%
data = Z_norm
L= len(data)
#k = int((len(data) + 1)/250) # k varies from 4 to 8
N=20
B  =60
E =0#round((N*B - L)/(N-1))
print(B)
print(E)
print(L)
max(np.abs(data))
f, t, Zxx = signal.stft(z,fs = 1, nperseg=B,noverlap= E)
print(len(t))
print(len(data))
X =plt.pcolormesh(t, f, np.abs(Zxx) ,vmax=max(np.abs(data)),shading='gouraud')
plt.title('STFT Magnitude')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.ylim([0,0.5])
plt.show()
# Out:
# 60
# 0
# 400
# 8
# 400

# %%
bin_xn = bin_val.tolist()
ht = bin_xn
ind = list(range(len(ht)))
plt.bar(ind, ht)
plt.show()

# %%
f, t, Zxx = signal.stft(x, Fs, nperseg=20)
X =plt.pcolormesh(t, f, np.abs(Zxx)**2, vmin=0, vmax=amp, shading='gouraud')
plt.title('STFT Magnitude')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()

# %%
X

# %%
Fs = 2
t = np.linspace(0,400,400)
f = 1/100
x =(np.sin(2*np.pi*10*t))+(np.sin(2*np.pi*20*t))
y =(np.sin(2*np.pi*50*t))+(np.sin(2*np.pi*60*t))
x = x+y

# %%
plt.plot(t,x)

# %%
Z = np.fft.fft(x)
Z_norm = abs(Z)
Z_norm = Z_norm/ max(Z_norm)
plt.plot(Z_norm)

# %%
L = len(Z_norm)+1
k = int((len(Z_norm) + 1)/250) # k varies from 4 to 8
N = 100
B  = 10*k ### chose the factor to be greater than (250/N), for overlap to exist
E =round((N*B - L)/(N-1))
step_size = B-E
bucket_size = B
bin_val=[]
for a in range(N-1):
    bin_val = np.append(bin_val, sum(np.abs(Z_norm[a*step_size:((a*step_size)+bucket_size)])))
    if (a == (N-2)):
        print(len(Z_norm),sum(np.abs(Z_norm[a*step_size:]))) 
            
bin_val = np.append(bin_val, sum(np.abs(Z_norm[-(bucket_size):])))
bin_val = bin_val/(max(bin_val))
print(E)
# Out:
# 400 0.006340139207167816
# 6

# %%
bin_xn = bin_val.tolist()
ht = bin_xn
ind = list(range(len(ht)))
plt.bar(ind, ht)
plt.show()

# %%
f, t, Zxx = signal.stft(x, Fs, nperseg=20)
plt.pcolormesh(t, f, np.abs(Zxx)**2, vmin=0, vmax=amp, shading='gouraud')
plt.title('STFT Magnitude')
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [sec]')
plt.show()

# %%
a = np.array([[1,2],[3,4]])

# %%
a.flatten()
# Out:
# array([1, 2, 3, 4])
