# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fftpack  import fft
from scipy.fftpack import ifft
import cmath
import plotly
import plotly.express as px

# %%
Fs = 2
t = np.linspace(0,400,800)
f = 1/100
x =(np.sin(2*np.pi*10*t))
y =(np.sin(2*np.pi*10*t))
plt.plot(t,x)
#plt.plot(t,y)
plt.title('Sine')
# Out:
# Text(0.5, 1.0, 'Sine')

# %%
# Out:
# array([0.        , 0.00125313, 0.00250627, 0.0037594 , 0.00501253,
#        0.00626566, 0.0075188 , 0.00877193, 0.01002506, 0.0112782 ,
#        0.01253133, 0.01378446, 0.01503759, 0.01629073, 0.01754386,
#        0.01879699, 0.02005013, 0.02130326, 0.02255639, 0.02380952,
#        0.02506266, 0.02631579, 0.02756892, 0.02882206, 0.03007519,
#        0.03132832, 0.03258145, 0.03383459, 0.03508772, 0.03634085,
#        0.03759398, 0.03884712, 0.04010025, 0.04135338, 0.04260652,
#        0.04385965, 0.04511278, 0.04636591, 0.04761905, 0.04887218,
#        0.05012531, 0.05137845, 0.05263158, 0.05388471, 0.05513784,
#        0.05639098, 0.05764411, 0.05889724, 0.06015038, 0.06140351,
#        0.06265664, 0.06390977, 0.06516291, 0.06641604, 0.06766917,
#        0.06892231, 0.07017544, 0.07142857, 0.0726817 , 0.07393484,
#        0.07518797, 0.0764411 , 0.07769424, 0.07894737, 0.0802005 ,
#        0.08145363, 0.08270677, 0.0839599 , 0.08521303, 0.08646617,
#        0.0877193 , 0.08897243, 0.09022556, 0.0914787 , 0.09273183,
#        0.09398496, 0.0952381 , 0.09649123, 0.09774436, 0.09899749,
#        0.10025063, 0.10150376, 0.10275689, 0.10401003, 0.10526316,
#        0.10651629, 0.10776942, 0.10902256, 0.11027569, 0.11152882,
#        0.11278195, 0.11403509, 0.11528822, 0.11654135, 0.11779449,
#        0.11904762, 0.12030075, 0.12155388, 0.12280702, 0.12406015,
#        0.12531328, 0.12656642, 0.12781955, 0.12907268, 0.13032581,
#        0.13157895, 0.13283208, 0.13408521, 0.13533835, 0.13659148,
#        0.13784461, 0.13909774, 0.14035088, 0.14160401, 0.14285714,
#        0.14411028, 0.14536341, 0.14661654, 0.14786967, 0.14912281,
#        0.15037594, 0.15162907, 0.15288221, 0.15413534, 0.15538847,
#        0.1566416 , 0.15789474, 0.15914787, 0.160401  , 0.16165414,
#        0.16290727, 0.1641604 , 0.16541353, 0.16666667, 0.1679198 ,
#        0.16917293, 0.17042607, 0.1716792 , 0.17293233, 0.17418546,
#        0.1754386 , 0.17669173, 0.17794486, 0.17919799, 0.18045113,
#        0.18170426, 0.18295739, 0.18421053, 0.18546366, 0.18671679,
#        0.18796992, 0.18922306, 0.19047619, 0.19172932, 0.19298246,
#        0.19423559, 0.19548872, 0.19674185, 0.19799499, 0.19924812,
#        0.20050125, 0.20175439, 0.20300752, 0.20426065, 0.20551378,
#        0.20676692, 0.20802005, 0.20927318, 0.21052632, 0.21177945,
#        0.21303258, 0.21428571, 0.21553885, 0.21679198, 0.21804511,
#        0.21929825, 0.22055138, 0.22180451, 0.22305764, 0.22431078,
#        0.47619048, 0.47744361, 0.47869674, 0.47994987, 0.48120301,
#        0.48245614, 0.48370927, 0.48496241, 0.48621554, 0.48746867,
#        0.4887218 , 0.48997494, 0.49122807, 0.4924812 , 0.49373434,
#        0.49498747, 0.4962406 , 0.49749373, 0.49874687, 0.5       ])

# %%
z=[]
for i in range(0,800):
    z.append(complex(x[i],-1*y[i]))

# %%
Z = np.fft.fft(z)

fft_im=[]
fft_r =[]
for a in Z:
    fft_im.append(a.imag)
    fft_r.append(a.real)

# %%
mag=[]
phase =[]
for a in Z:
    mag.append(abs(a))
    phase.append(())

# %%
fig, ax = plt.subplots(2,2,figsize =(15,15))
ax[0,0].plot(t,fft_im)

ax[0,1].plot(t,fft_r)

ax[1,0].plot(t,mag)

ax[1,1].plot(t,phase)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-73-af0cd70e0aef> in <module>
#       6 ax[1,0].plot(t,mag)
#       7
# ----> 8 ax[1,1].plot(t,phase)
#
# C:\Python\Python37\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1644         """
#    1645         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1646         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1647         for line in lines:
#    1648             self.add_line(line)
#
# C:\Python\Python37\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# C:\Python\Python37\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     362                 "non-matching shapes is deprecated.")
#     363         return [func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
# --> 364                 for j in range(max(ncx, ncy))]
#     365
#     366
#
# C:\Python\Python37\lib\site-packages\matplotlib\axes\_base.py in <listcomp>(.0)
#     362                 "non-matching shapes is deprecated.")
#     363         return [func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
# --> 364                 for j in range(max(ncx, ncy))]
#     365
#     366
#
# ZeroDivisionError: integer division or modulo by zero

# %%
Z[:30]
# Out:
# array([ 3.48959056e-12-1.00564945e-10j,  7.42712788e-02-3.08565265e-01j,
#         1.52086794e-01-6.82085390e-01j,  2.36497451e-01-1.26123153e+00j,
#         3.40543577e-01-2.67956131e+00j,  8.23885425e+00-4.00304412e+02j,
#         4.17811636e-01+1.82195033e+00j,  5.44875559e-01+1.11974349e-01j,
#         6.77010968e-01-1.15954865e+00j,  8.75836017e-01-3.84553582e+00j,
#         1.65098993e+01-3.98637608e+02j,  7.09274326e-01+5.91713677e+00j,
#         9.39654040e-01+3.29906745e+00j,  1.11818891e+00+2.40561802e+00j,
#         1.29955011e+00+1.94848896e+00j,  1.49935055e+00+1.67091214e+00j,
#         1.72874698e+00+1.48723828e+00j,  2.00054557e+00+1.36113138e+00j,
#         2.33279115e+00+1.27533221e+00j,  2.75385397e+00+1.22193512e+00j,
#         3.31268805e+00+1.19929477e+00j,  4.10363190e+00+1.21260471e+00j,
#         5.33912000e+00+1.28014674e+00j,  7.63407304e+00+1.46087258e+00j,
#         1.39321005e+01+2.04416366e+00j,  3.99802967e+02+4.00669366e+01j,
#        -9.71990648e+00-3.39476036e-01j, -1.97595534e+00+4.16121459e-01j,
#         2.56572796e+00+8.82561805e-01j,  1.06691727e+01+1.79496341e+00j])

# %%
x1 =(np.sin(2*np.pi*10*t))
y1 =(np.ones(800))

# %%
z1=[]
for i in range(0,800):
    z1.append(complex(x1[i],y1[i]))

# %%
Z1 = np.fft.fft(y)

fft1_im=[]
fft1_r =[]
for a in Z1:
    fft1_im.append(a.imag)
    fft1_r.append(a.real)

# %%
import plotly.express as px
import plotly
fig = px.bar(x=t,y =fft_r)
plotly.offline.plot(fig)
# Out:
# 'temp-plot.html'

# %%
plt.plot(fft1_im)

# %%
s=[]
for i in range(0,800):
    s.append(complex(0,0))

# %%
s[10]=1 +0j
s[20]= 1 +0j
s[50] = 0+ 0j
s[60] = 0 + 0j

# %%
S = np.fft.fft(s)
t = np.linspace(0,1,800)

# %%
plt.plot(S)
# Out:
# C:\Python\Python37\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning:
#
# Casting complex values to real discards the imaginary part

# %%
S[10]
# Out:
# (0.7071067811865475-1.7071067811865475j)

# %%
# Out:
# array([-8.26815569e-02-2.24118167e-01j, -8.28803340e-02-2.30208984e-01j,
#        -8.30942217e-02-2.36617699e-01j, -8.33248178e-02-2.43371877e-01j,
#        -8.35739415e-02-2.50502455e-01j, -8.38436709e-02-2.58044286e-01j,
#        -8.41363903e-02-2.66036795e-01j, -8.44548464e-02-2.74524769e-01j,
#        -8.48022181e-02-2.83559319e-01j, -8.51822025e-02-2.93199064e-01j,
#        -8.55991219e-02-3.03511592e-01j, -8.60580580e-02-3.14575279e-01j,
#        -8.65650222e-02-3.26481579e-01j, -8.71271720e-02-3.39337931e-01j,
#        -8.77530918e-02-3.53271481e-01j, -8.84531572e-02-3.68433915e-01j,
#        -8.92400175e-02-3.85007805e-01j, -9.01292398e-02-4.03215040e-01j,
#        -9.11401830e-02-4.23328229e-01j, -9.22972034e-02-4.45686337e-01j,
#        -9.36313456e-02-4.70716561e-01j, -9.51827642e-02-4.98965524e-01j,
#        -9.70042715e-02-5.31144837e-01j, -9.91666691e-02-5.68199394e-01j,
#        -1.01767005e-01-6.11412871e-01j, -1.04941811e-01-6.62576520e-01j,
#        -1.08889208e-01-7.24270564e-01j, -1.13907666e-01-8.00356978e-01j,
#        -1.20468152e-01-8.96895690e-01j, -1.29358772e-01-1.02398012e+00j,
#        -1.42003955e-01-1.19978536e+00j, -1.61265566e-01-1.46072522e+00j,
#        -1.93859974e-01-1.89209132e+00j, -2.60118852e-01-2.75177002e+00j,
#        -4.63821548e-01-5.35532658e+00j,  1.56559106e+01+1.98927206e+02j,
#         3.26353009e-01+4.60925856e+00j,  1.37766507e-01+2.18973593e+00j,
#         7.47569790e-02+1.35839461e+00j,  4.38539514e-02+9.29920794e-01j,
#         2.60172102e-02+6.62182217e-01j,  1.48775697e-02+4.73411945e-01j,
#         7.72842147e-03+3.27943694e-01j,  3.25688533e-03+2.07322707e-01j,
#         7.89672350e-04+1.00542139e-01j])
