# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.fftpack  import fft
from scipy.fftpack import ifft

# %%
Fs = 1
t = np.arange(0,400,1/Fs)
f = 1/100
x =50*( np.sin(2*np.pi*f*t))

plt.plot(t,x)
plt.title('Sine')
# Out:
# Text(0.5, 1.0, 'Sine')

# %%
N = np.size(t)
freq = (np.linspace(0,400,N))*(Fs/2)
np.size(freq)
# Out:
# 400

# %%
X = np.fft.fft(x)

X1 = (2/N)*abs((X[0:np.size(freq)]))
plt.plot(X3)
plt.title('fourier')
# Out:
# Text(0.5, 1.0, 'fourier')

# %%
print(X1[0:10])
print(X1[390:])
# Out:
# [1.08989886e-15 2.95454488e-15 2.44124774e-15 8.49723923e-15
#  5.00000000e+01 1.12157693e-14 5.92605598e-15 4.40831688e-15
#  3.80323589e-15 2.49074350e-15]
# [3.19073078e-15 2.49074350e-15 3.80323589e-15 4.40831688e-15
#  5.92605598e-15 1.12157693e-14 5.00000000e+01 8.49723923e-15
#  2.44124774e-15 2.95454488e-15]

# %%
X3  =  np.insert(X1,0,np.zeros(1))
X3  =  np.insert(X3,0,np.zeros(3))
X3  =  np.insert(X3,100,np.zeros(96))
np.size(X3)
# Out:
# 500

# %%
x_reformed = ifft(X3)

# %%
t_long = np.arange(0,500,1/Fs)
plt.plot(t_long,x_reformed)
plt.title('Reconstructed')
# Out:
# C:\Python\Python37\lib\site-packages\numpy\core\_asarray.py:85: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# Text(0.5, 1.0, 'Reconstructed')
